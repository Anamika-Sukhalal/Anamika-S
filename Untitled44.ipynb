# %% [markdown]
# <a href="https://colab.research.google.com/github/Anamika-Sukhalal/Anamika-S/blob/main/Untitled44.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welcome to university chatbot")
print("Type 'exit' to stop\n")
while True:
  user_input = input("you :  ").lower()
  if user_input == "exit":
    print("good day")
  elif user_input == "admission":
    print ("admission start in march")
  elif user_input == "fee":
    print("fee details are available in the accounts section")
  elif user_input == "exam":
    print("exam start in march")
  else:
    print("sorry i dont know")
# Out:
# welcome to university chatbot
# Type 'exit' to stop
#
# you :  hi
# sorry i dont know
# you :  anna
# sorry i dont know
